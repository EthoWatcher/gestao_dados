# %%
import fusao_variaveis as fus
import pandas as pd
from bson.objectid import ObjectId

# %%
dict_query = { "$and": [{"id_experimento": ObjectId("5ea1a82993f4d56ba41e567d")}, 
                        {"var_ind.sexo":"macho"},
                        {"var_ind.dosagem": "flx2.5mg"}]}

# %%
fs = fus.Fusao_variaveis(dict_query)

# %%
# fs.set_variaveis_rastreamento(["@Vd", "@Van"])
# fs.set_variaveis_etografia(["nome"])
# list_des_etografia =["nome"]
# fs.set_variaveis_etografia(list_des_etografia)



lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)


li_str_descritores = ["duracao", "frequencia", "duracao_total", "path_experimento"]
li_str_categora = ["Immobility"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#     d_e_Immobility_s  f_e_Immobility_s  d_total_experimento        categoria  \
# 0          31.466667                41           297.500000  joao_legal/path
# 1          34.566667                44           247.800000  joao_legal/path
# 2          47.900000                54           247.800000  joao_legal/path
# 3          33.600000                38           244.400000  joao_legal/path
# 4          47.466667                53           246.433333  joao_legal/path
# 5         119.900000                61           246.666667  joao_legal/path
# 6          64.633333                45           245.700000  joao_legal/path
# 7          87.966667               105           247.500000  joao_legal/path
# 8          79.466667                81           247.700000  joao_legal/path
# 9          92.466667                81           247.233333  joao_legal/path
# 10         92.233333                90           247.700000  joao_legal/path
# 11         92.666667                83           246.900000  joao_legal/path
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5ea2305793f4d55ef029829b  5ea2305793f4d55ef0298297  macho  flx2.5mg
# 1   5ea2305793f4d55ef02982a4  5ea2305793f4d55ef02982a0  macho  flx2.5mg
# 2   5ea2305793f4d55ef02982ad  5ea2305793f4d55ef02982a9  macho  flx2.5mg
# 3   5ea2305893f4d55ef02982b6  5ea2305893f4d55ef02982b2  macho  flx2.5mg
# 4   5ea2305893f4d55ef02982bf  5ea2305893f4d55ef02982bb  macho  flx2.5mg
# 5   5ea2305893f4d55ef02982c8  5ea2305893f4d55ef02982c4  macho  flx2.5mg
# 6   5ea2305993f4d55ef02982d1  5ea2305993f4d55ef02982cd  macho  flx2.5mg
# 7   5ea2305993f4d55ef02982da  5ea2305993f4d55ef02982d6  macho  flx2.5mg
# 8   5ea2305993f4d55ef02982e3  5ea2305993f4d55ef02982df  macho  flx2.5mg
# 9   5ea2305a93f4d55ef02982ec  5ea2305a93f4d55ef02982e8  macho  flx2.5mg
# 10  5ea2305a93f4d55ef02982f5  5ea2305a93f4d55ef02982f1  macho  flx2.5mg
# 11  5ea2305a93f4d55ef02982fe  5ea2305a93f4d55ef02982fa  macho  flx2.5mg
#
#    unidade
# 0       A1
# 1       A2
# 2       A2
# 3       A2
# 4       A2
# 5       A3
# 6       A4
# 7       A5
# 8       A6
# 9       A6
# 10      A6
# 11      A6
