# %%
import deposito_watcher.fusao_variaveis as fus
import pandas as pd
from bson.objectid import ObjectId

# %%
# dict_query = { "$and": [{"id_experimento": ObjectId("5f4f8f39c66cad3eb1dd0d50")}, 
#                         {"var_ind.sexo":"macho"},{"$or": [{"var_ind.dosagem": "flx2.5mg"},
#                                  {"var_ind.dosagem": "veiculo"} ]}
#                         ]}


# dict_query = { "$and": [{"id_experimento": ObjectId("5f8f5503d3d64947e0da22e0")}, 
#                         {"var_ind.sexo":"macho"},{"$or": [{"var_ind.dosagem": "flx2.5mg"},
#                                  {"var_ind.dosagem": "veiculo"} ]}
#                         ]}


# dict_query = { "$and": [{"id_experimento": ObjectId("5f8f5503d3d64947e0da22e0")}, 
#                         {"$or": [{"var_ind.sexo":"macho"}, {"var_ind.sexo":"femea"} ]},{"$or": [{"var_ind.dosagem": "flx2.5mg"},
#                                  {"var_ind.dosagem": "veiculo"} ]}
#                         ]}



dict_query = { "$and": [{"id_experimento": ObjectId("5f8f5503d3d64947e0da22e0")}, 
                        {"var_ind.sexo":"macho"}, {"$or": [{"var_ind.dosagem": "flx2.5mg"},
                                 {"var_ind.dosagem": "veiculo"} ]}
                        ]}

# %%
fs = fus.Fusao_variaveis(dict_query)

fs.set_variaveis_rastreamento(["@Vd", "@Van"])
fs.set_variaveis_etografia(["nome", "trecho", "q_inicial", "q_final"])
li_str_descritores = ["duracao", "frequencia", "duracao_total"]
li_str_categora = ["Immobility", "Swimming"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#          categoria  trecho  q_inicio  q_fim                      id_j    @f  \
# 0       Immobility       0       155    167  5f8f550bd3d64947e0da2353   155
# 1       Immobility       0       155    167  5f8f550bd3d64947e0da2353   156
# 2       Immobility       0       155    167  5f8f550bd3d64947e0da2353   157
# 3       Immobility       0       155    167  5f8f550bd3d64947e0da2353   158
# 4       Immobility       0       155    167  5f8f550bd3d64947e0da2353   159
# ...            ...     ...       ...    ...                       ...   ...
# 261003   Undefined     211      7515   7540  5f8f5512d3d64947e0da23cb  7535
# 261004   Undefined     211      7515   7540  5f8f5512d3d64947e0da23cb  7536
# 261005   Undefined     211      7515   7540  5f8f5512d3d64947e0da23cb  7537
# 261006   Undefined     211      7515   7540  5f8f5512d3d64947e0da23cb  7538
# 261007   Undefined     211      7515   7540  5f8f5512d3d64947e0da23cb  7539
#
#               @Vd      @Van  d_e_Immobility_s  f_e_Immobility_s  \
# 0        0.000000   0.00000         64.633333                45
# 1        6.622321   1.54842         64.633333                45
# 2        0.000000   0.00000         64.633333                45
# 3       45.432280  10.62290         64.633333                45
# 4        0.000000   0.00000         64.633333                45
# ...           ...       ...               ...               ...
# 261003   0.000000   0.00000        128.533333                85
# 261004   0.000000   0.00000        128.533333                85
# 261005   0.000000   0.00000        128.533333                85
# 261006   0.000000   0.00000        128.533333                85
# 261007  -6.224857  -1.60000        128.533333                85
#
#         d_total_experimento  d_e_Swimming_s  f_e_Swimming_s  \
# 0                245.700000       12.966667              29
# 1                245.700000       12.966667              29
# 2                245.700000       12.966667              29
# 3                245.700000       12.966667              29
# 4                245.700000       12.966667              29
# ...                     ...             ...             ...
# 261003           247.666667       22.166667              52
# 261004           247.666667       22.166667              52
# 261005           247.666667       22.166667              52
# 261006           247.666667       22.166667              52
# 261007           247.666667       22.166667              52
#
#         d_total_experimento                    id_eto
# 0                245.700000  5f8f550bd3d64947e0da2357
# 1                245.700000  5f8f550bd3d64947e0da2357
# 2                245.700000  5f8f550bd3d64947e0da2357
# 3                245.700000  5f8f550bd3d64947e0da2357
# 4                245.700000  5f8f550bd3d64947e0da2357
# ...                     ...                       ...
# 261003           247.666667  5f8f5512d3d64947e0da23cf
# 261004           247.666667  5f8f5512d3d64947e0da23cf
# 261005           247.666667  5f8f5512d3d64947e0da23cf
# 261006           247.666667  5f8f5512d3d64947e0da23cf
# 261007           247.666667  5f8f5512d3d64947e0da23cf
#
# [261008 rows x 15 columns]

# %%
df.to_excel("teste.xlsx")
