# %%
import calc_bayes_grid as grid_c

# %%
import matplotlib.pyplot as plt

# %%
qnt_probabilidades = 100

# %%
grid = [i for i, x in enumerate(range(qnt_probabilidades))]

# %% [markdown]
# # Probabilidade de imobilidades que serão testadas

# %%
lis_prob_uniform = grid_c.calc_list_probabilidades_testadas(qnt_probabilidades)
lis_prob_uniform
plt.scatter(grid , lis_prob_uniform)

# %%
prior = grid_c.cal_prior_uni(qnt_probabilidades)
plt.scatter(grid , prior)

# %%
like = grid_c.calc_likehood_bino(31,297,lis_prob_uniform)
plt.scatter(grid , like)

# %% [markdown]
# # Calculando posterior

# %%
post = grid_c.calc_post_bayes(like,prior)
plt.scatter(grid , post)

# %%
like_2 = grid_c.calc_likehood_bino(34,247, lis_prob_uniform)
post_2 = grid_c.calc_post_bayes(like_2, post)
plt.scatter(grid , post_2)

# %%
like_3 = grid_c.calc_likehood_bino(47,247, lis_prob_uniform)
post_3 = grid_c.calc_post_bayes(like_3, post_2)
plt.scatter(grid , post_3)

# %%
like_4 = grid_c.calc_likehood_bino(47,247, lis_prob_uniform)
post_4 = grid_c.calc_post_bayes(like_4, post_3)
plt.scatter(lis_prob_uniform , post_3)
