# %%
import fusao_variaveis as fus
import pandas as pd
from bson.objectid import ObjectId

# %%
dict_query = { "$and": [{"id_experimento": ObjectId("5ea1a82993f4d56ba41e567d")}, 
                        {"var_ind.sexo":"femea"},
                        {"$or": [{"var_ind.dosagem": "flx2.5mg"},
                                 {"var_ind.dosagem": "veiculo"}
                        ]}]}

# %%
pd.set_option('display.max_colwidth', -1)

# %%
fs = fus.Fusao_variaveis(dict_query)

# %%
# fs.set_variaveis_rastreamento(["@Vd", "@Van"])
# fs.set_variaveis_etografia(["nome"])
# list_des_etografia =["nome"]
# fs.set_variaveis_etografia(list_des_etografia)



lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)


li_str_descritores = ["duracao", "duracao_total", "path_experimento"]
li_str_categora = ["Immobility"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#     d_e_Immobility_s  d_total_experimento  \
# 0   72.500000         247.033333
# 1   40.000000         248.433333
# 2   124.666667        246.100000
# 3   101.500000        248.000000
# 4   38.766667         246.166667
# 5   63.800000         245.266667
# 6   68.666667         245.900000
# 7   200.166667        247.400000
# 8   51.300000         249.533333
# 9   82.933333         247.066667
# 10  85.200000         248.566667
# 11  48.133333         246.900000
# 12  34.100000         249.000000
# 13  75.166667         247.166667
# 14  116.366667        247.466667
# 15  107.933333        247.266667
# 16  75.533333         247.066667
#
#                                                       path_experimento  \
# 0   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/7e3z1b2.vxml
# 1   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/8e8z9c.vxml
# 2   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/9ez5d9.vxml
# 3   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/7e3z5f1.vxml
# 4   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/e1z1g1.vxml
# 5   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1e3z1h4.vxml
# 6   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e3z2i.vxml
# 7   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/7e1z9j.vxml
# 8   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5o6zb7.vxml
# 9   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1o5z6c.vxml
# 10  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/7o7z2d99.vxml
# 11  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o3z4f.vxml
# 12  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o5z8g2.vxml
# 13  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2o3zh5.vxml
# 14  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/33o6z89i.vxml
# 15  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/o22z1j5.vxml
# 16  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2o44z7k.vxml
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5ea2305b93f4d55ef0298307  5ea2305b93f4d55ef0298303  femea  flx2.5mg
# 1   5ea2305b93f4d55ef0298310  5ea2305b93f4d55ef029830c  femea  flx2.5mg
# 2   5ea2305b93f4d55ef0298319  5ea2305b93f4d55ef0298315  femea  flx2.5mg
# 3   5ea2305c93f4d55ef0298322  5ea2305c93f4d55ef029831e  femea  flx2.5mg
# 4   5ea2305c93f4d55ef029832b  5ea2305c93f4d55ef0298327  femea  flx2.5mg
# 5   5ea2305c93f4d55ef0298334  5ea2305c93f4d55ef0298330  femea  flx2.5mg
# 6   5ea2305d93f4d55ef029833d  5ea2305d93f4d55ef0298339  femea  flx2.5mg
# 7   5ea2305d93f4d55ef0298346  5ea2305d93f4d55ef0298342  femea  flx2.5mg
# 8   5ea2305f93f4d55ef0298385  5ea2305f93f4d55ef0298381  femea  veiculo
# 9   5ea2306093f4d55ef029838e  5ea2306093f4d55ef029838a  femea  veiculo
# 10  5ea2306093f4d55ef0298397  5ea2306093f4d55ef0298393  femea  veiculo
# 11  5ea2306193f4d55ef02983a0  5ea2306193f4d55ef029839c  femea  veiculo
# 12  5ea2306193f4d55ef02983a9  5ea2306193f4d55ef02983a5  femea  veiculo
# 13  5ea2306193f4d55ef02983b2  5ea2306193f4d55ef02983ae  femea  veiculo
# 14  5ea2306293f4d55ef02983bb  5ea2306293f4d55ef02983b7  femea  veiculo
# 15  5ea2306293f4d55ef02983c4  5ea2306293f4d55ef02983c0  femea  veiculo
# 16  5ea2306293f4d55ef02983cd  5ea2306293f4d55ef02983c9  femea  veiculo
#
#    unidade
# 0   A1
# 1   A2
# 2   A3
# 3   A4
# 4   A5
# 5   A6
# 6   A7
# 7   A8
# 8   A1
# 9   A2
# 10  A3
# 11  A4
# 12  A5
# 13  A6
# 14  A7
# 15  A8
# 16  A9

# %%
# df.loc[1:4]["path_experimento"]
# "Feita do mesmo arquivo de vídeo calibrado"


# Nenhum video foi feito a etografia usando esse xml
# db.getCollection('Etografia').find({"analiseEtografica.dadosVideoAnalisado.nomeVxml": "C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5bis4.vxml"})

# %%
# df = df.drop([2, 3, 4])
# df

# %%
# df = df.drop([9, 10, 11])
# df

# %%
df.to_csv('Dados_duracao_femea.csv', index=False)
