# %%
import pandas as pd
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %%
import deposito_watcher.video as v

# %%
PATH_ARQUIVOS = "C:/dados_gian_mongo_arrumados/arquivos_videos/"

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\zn_jo\.conda\envs\doutorado_36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
df = pd.read_csv("dados_selecionados_para_cnn.csv")
df
# Out:
#       categoria  trecho  q_inicio  q_fim  q_inicio_analise   fps  \
# 0    Immobility  44      2694      2713   142               30.0
# 1    Immobility  84      3881      3903   142               30.0
# 2    Immobility  96      4016      4030   142               30.0
# 3    Immobility  121     4599      4621   142               30.0
# 4    Immobility  132     5052      5064   142               30.0
# ..          ...  ...      ...       ...   ...                ...
# 994  Diving      22      842       888    114               30.0
# 995  Diving      22      842       888    114               30.0
# 996  Diving      22      842       888    114               30.0
# 997  Diving      22      842       888    114               30.0
# 998  Diving      22      842       888    114               30.0
#
#                          id_j    @f        @Vd       @Van   sexo   dosagem  \
# 0    5f8f5508d3d64947e0da232b  2694 -1.535516  -0.410965   macho  flx2.5mg
# 1    5f8f5508d3d64947e0da232b  3884 -31.105965 -8.325190   macho  flx2.5mg
# 2    5f8f5508d3d64947e0da232b  4020 -8.123945  -2.174290   macho  flx2.5mg
# 3    5f8f5508d3d64947e0da232b  4613  14.611885  3.910720   macho  flx2.5mg
# 4    5f8f5508d3d64947e0da232b  5057  0.260183   0.069635   macho  flx2.5mg
# ..                        ...   ...       ...        ...     ...       ...
# 994  5f8f551ad3d64947e0da244b  847  -57.237064 -15.817100  femea  flx1mg
# 995  5f8f551ad3d64947e0da244b  850  -18.767284 -5.186220   femea  flx1mg
# 996  5f8f551ad3d64947e0da244b  862  -13.334954 -3.685030   femea  flx1mg
# 997  5f8f551ad3d64947e0da244b  865   18.093413  5.000000   femea  flx1mg
# 998  5f8f551ad3d64947e0da244b  878  -25.172135 -6.956160   femea  flx1mg
#
#     unidade                  id_video
# 0    A2      5f8f5508d3d64947e0da232d
# 1    A2      5f8f5508d3d64947e0da232d
# 2    A2      5f8f5508d3d64947e0da232d
# 3    A2      5f8f5508d3d64947e0da232d
# 4    A2      5f8f5508d3d64947e0da232d
# ..   ..                           ...
# 994  A3      5f8f551ad3d64947e0da244d
# 995  A3      5f8f551ad3d64947e0da244d
# 996  A3      5f8f551ad3d64947e0da244d
# 997  A3      5f8f551ad3d64947e0da244d
# 998  A3      5f8f551ad3d64947e0da244d
#
# [999 rows x 14 columns]

# %%
t = v.Tocador_video(PATH_ARQUIVOS, df["id_video"].iloc[0])

# %%
plt
.plot(np.random.rand(10))

def onclick(event):
    print('%s click: button=%d, x=%d, y=%d, xdata=%f, ydata=%f' %
          ('double' if event.dblclick else 'single', event.button,
           event.x, event.y, event.xdata, event.ydata))

cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5ad7437aba45> in <module>()
#       6            event.x, event.y, event.xdata, event.ydata))
#       7
# ----> 8 cid = fig.canvas.mpl_connect('button_press_event', onclick)
#
# NameError: name 'fig' is not defined

# %%
q = t.get_quadro(df["@f"].iloc[0])

imagme = v.c_image_to_np(v.c_64_2_image(q))
plt.savefig('foo.png')
# handler = open("ete.jpg", "wb+")
# handler.write(q.decode("base64"))
# handler.close()
# Out:
# array([[[247, 255, 254],
#         [247, 255, 254],
#         [249, 255, 254],
#         ...,
#         [251, 255, 255],
#         [251, 255, 255],
#         [251, 255, 255]],
#
#        [[249, 255, 254],
#         [249, 255, 254],
#         [250, 255, 254],
#         ...,
#         [251, 255, 255],
#         [251, 255, 255],
#         [251, 255, 255]],
#
#        [[252, 254, 254],
#         [252, 254, 254],
#         [252, 254, 254],
#         ...,
#         [251, 255, 255],
#         [251, 255, 255],
#         [251, 255, 255]],
#
#        ...,
#
#        [[130, 164, 170],
#         [160, 194, 200],
#         [159, 195, 201],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[151, 179, 186],
#         [177, 206, 213],
#         [177, 209, 215],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[141, 167, 174],
#         [163, 191, 198],
#         [165, 194, 201],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]]], dtype=uint8)

# %%
# df_machos_veiculo = df[(df["dosagem"] == "veiculo") & (df["categoria"] == "Headshaking") & (df["unidade"] == "A1") ]
# df_machos_veiculo
# df_machos_veiculo.to_csv('machos_veiculo_imobilidade.csv', index=False)

# %%
# load image using cv2....and do processing.

# %%
# def mostra_faixas(df):
#     for index, row in df.iterrows():

# %%
# def mostra_faixas(df):
#     for index, row in df.iterrows():
# #         linha_df_mostrado = df_machos_veiculo.iloc[i]
#         tocador = v.Tocador_video(PATH_ARQUIVOS, row["id_video"])
#         for imagem in tocador.get_video_gerador(row["q_inicio"],row["q_fim"]):                                                        
#             np_image = v.c_image_to_np(imagem)
#     #     plt.imshow(cv2.cvtColor(np_image, cv2.COLOR_BGR2RGB))
#         # as opencv loads in BGR format by default, we want to show it in RGB.
#             plt.show()
#             cv2.imshow("teste", cv2.resize(np_image  , (720 , 540)))
#             k = cv2.waitKey(int(1/30*1000))
#             if k == 27: # nexkt
#                 break
# #             print(k)
            
#     cv2.destroyWindow('teste')

# %%
#Swimming
# Climbing
# mostra_faixas(df[(df["dosagem"] == "veiculo") & (df["categoria"] == "Climbing") & (df["unidade"] == "A3") ])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ec5558ab484b> in <module>()
#       1 #Swimming
#       2 # Climbing
# ----> 3 mostra_faixas(df[(df["dosagem"] == "veiculo") & (df["categoria"] == "Climbing") & (df["unidade"] == "A3") ])
#
# <ipython-input-17-2bce4a9ce17e> in mostra_faixas(df)
#       9             plt.show()
#      10             cv2.imshow("teste", cv2.resize(np_image  , (720 , 540)))
# ---> 11             k = cv2.waitKey(int(1/30*1000))
#      12             if k == 27: # nexkt
#      13                 break
#
# KeyboardInterrupt:

# %%
# for i in range(20):
#     linha_df_mostrado = df_machos_veiculo.iloc[i]
#     tocador = v.Tocador_video(PATH_ARQUIVOS, linha_df_mostrado["id_video"])
#     for imagem in tocador.get_video_gerador(linha_df_mostrado["q_inicio"],linha_df_mostrado["q_fim"]):                                                        
#         np_image = v.c_image_to_np(imagem)
#     #     plt.imshow(cv2.cvtColor(np_image, cv2.COLOR_BGR2RGB))
#         # as opencv loads in BGR format by default, we want to show it in RGB.
#         plt.show()
#         cv2.imshow("teste", np_image)
#         k = cv2.waitKey(int(1/30*1000))

# cv2.destroyWindow('teste')
# # df_machos_tratados = df[(df["dosagem"] == "flx2.5mg")& (df["categoria"] == "Immobility")]
# # df_machos_tratados.to_csv('machos_flx25_imobilidade.csv', index=False)
