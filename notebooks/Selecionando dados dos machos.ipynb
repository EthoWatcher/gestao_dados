# %%
import deposito_watcher.fusao_variaveis as fus
import pandas as pd
from bson.objectid import ObjectId

# %%
dict_query = { "$and": [{"id_experimento": ObjectId("5f4f8f39c66cad3eb1dd0d50")}, 
                        {"var_ind.sexo":"macho"},
                        {"$or": [{"var_ind.dosagem": "flx2.5mg"},
                                 {"var_ind.dosagem": "veiculo"}
                        ]}]}

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# c:\users\zn_jo\miniconda3\envs\doutorado\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
fs = fus.Fusao_variaveis(dict_query)

# %%
# fs.set_variaveis_rastreamento(["@Vd", "@Van"])
# fs.set_variaveis_etografia(["nome"])
# list_des_etografia =["nome"]
# fs.set_variaveis_etografia(list_des_etografia)



lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)


li_str_descritores = ["duracao", "duracao_total", "path_experimento"]
li_str_categora = ["Immobility"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#     d_e_Immobility_s  d_total_experimento  \
# 0   31.466667         297.500000
# 1   34.566667         247.800000
# 2   47.900000         247.800000
# 3   33.600000         244.400000
# 4   47.466667         246.433333
# 5   119.900000        246.666667
# 6   64.633333         245.700000
# 7   87.966667         247.500000
# 8   79.466667         247.700000
# 9   92.466667         247.233333
# 10  92.233333         247.700000
# 11  92.666667         246.900000
# 12  54.900000         269.033333
# 13  128.533333        247.666667
# 14  87.866667         247.333333
# 15  58.066667         247.533333
# 16  109.000000        245.633333
# 17  75.400000         248.533333
#
#                                                          path_experimento  \
# 0   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1e4hb4.vxml
# 1   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 2   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 3   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/52e03hc52a.vxml
# 4   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/22e31hc25b.vxml
# 5   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3eh3d23.vxml
# 6   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e6hf2.vxml
# 7   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5eh7g8.vxml
# 8   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 9   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6bis4.vxml
# 10  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 11  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/9e5h4h6b.vxml
# 12  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2oh6b8.vxml
# 13  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/8o6hc5.vxml
# 14  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1oh5d5.vxml
# 15  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o8hf5.vxml
# 16  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3oh8g9.vxml
# 17  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5oh7h6.vxml
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5f4f8f3cc66cad3eb1dd0d97  5f4f8f3cc66cad3eb1dd0d93  macho  flx2.5mg
# 1   5f4f8f3cc66cad3eb1dd0d9f  5f4f8f3cc66cad3eb1dd0d9b  macho  flx2.5mg
# 2   5f4f8f3dc66cad3eb1dd0da7  5f4f8f3dc66cad3eb1dd0da3  macho  flx2.5mg
# 3   5f4f8f3dc66cad3eb1dd0daf  5f4f8f3dc66cad3eb1dd0dab  macho  flx2.5mg
# 4   5f4f8f3dc66cad3eb1dd0db7  5f4f8f3dc66cad3eb1dd0db3  macho  flx2.5mg
# 5   5f4f8f3ec66cad3eb1dd0dbf  5f4f8f3ec66cad3eb1dd0dbb  macho  flx2.5mg
# 6   5f4f8f3ec66cad3eb1dd0dc7  5f4f8f3ec66cad3eb1dd0dc3  macho  flx2.5mg
# 7   5f4f8f3ec66cad3eb1dd0dcf  5f4f8f3ec66cad3eb1dd0dcb  macho  flx2.5mg
# 8   5f4f8f3fc66cad3eb1dd0dd7  5f4f8f3fc66cad3eb1dd0dd3  macho  flx2.5mg
# 9   5f4f8f3fc66cad3eb1dd0ddf  5f4f8f3fc66cad3eb1dd0ddb  macho  flx2.5mg
# 10  5f4f8f3fc66cad3eb1dd0de7  5f4f8f3fc66cad3eb1dd0de3  macho  flx2.5mg
# 11  5f4f8f40c66cad3eb1dd0def  5f4f8f40c66cad3eb1dd0deb  macho  flx2.5mg
# 12  5f4f8f43c66cad3eb1dd0e37  5f4f8f43c66cad3eb1dd0e33  macho  veiculo
# 13  5f4f8f43c66cad3eb1dd0e3f  5f4f8f43c66cad3eb1dd0e3b  macho  veiculo
# 14  5f4f8f44c66cad3eb1dd0e47  5f4f8f44c66cad3eb1dd0e43  macho  veiculo
# 15  5f4f8f44c66cad3eb1dd0e4f  5f4f8f44c66cad3eb1dd0e4b  macho  veiculo
# 16  5f4f8f45c66cad3eb1dd0e57  5f4f8f45c66cad3eb1dd0e53  macho  veiculo
# 17  5f4f8f45c66cad3eb1dd0e5f  5f4f8f45c66cad3eb1dd0e5b  macho  veiculo
#
#    unidade
# 0   A1
# 1   A2
# 2   A2
# 3   A2
# 4   A2
# 5   A3
# 6   A4
# 7   A5
# 8   A6
# 9   A6
# 10  A6
# 11  A6
# 12  A1
# 13  A2
# 14  A3
# 15  A4
# 16  A5
# 17  A6

# %%
df.loc[1:4]["path_experimento"]
# "Feita do mesmo arquivo de vídeo calibrado"


# Nenhum video foi feito a etografia usando esse xml
# db.getCollection('Etografia').find({"analiseEtografica.dadosVideoAnalisado.nomeVxml": "C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5bis4.vxml"})
# Out:
# 1    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 2    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 3    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/52e03hc52a.vxml
# 4    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/22e31hc25b.vxml
# Name: path_experimento, dtype: object

# %%
df = df.drop([2, 3, 4])
df
# Out:
#     d_e_Immobility_s  d_total_experimento  \
# 0   31.466667         297.500000
# 1   34.566667         247.800000
# 5   119.900000        246.666667
# 6   64.633333         245.700000
# 7   87.966667         247.500000
# 8   79.466667         247.700000
# 9   92.466667         247.233333
# 10  92.233333         247.700000
# 11  92.666667         246.900000
# 12  54.900000         269.033333
# 13  128.533333        247.666667
# 14  87.866667         247.333333
# 15  58.066667         247.533333
# 16  109.000000        245.633333
# 17  75.400000         248.533333
#
#                                                          path_experimento  \
# 0   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1e4hb4.vxml
# 1   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 5   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3eh3d23.vxml
# 6   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e6hf2.vxml
# 7   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5eh7g8.vxml
# 8   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 9   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6bis4.vxml
# 10  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 11  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/9e5h4h6b.vxml
# 12  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2oh6b8.vxml
# 13  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/8o6hc5.vxml
# 14  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1oh5d5.vxml
# 15  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o8hf5.vxml
# 16  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3oh8g9.vxml
# 17  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5oh7h6.vxml
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5ea2305793f4d55ef029829b  5ea2305793f4d55ef0298297  macho  flx2.5mg
# 1   5ea2305793f4d55ef02982a4  5ea2305793f4d55ef02982a0  macho  flx2.5mg
# 5   5ea2305893f4d55ef02982c8  5ea2305893f4d55ef02982c4  macho  flx2.5mg
# 6   5ea2305993f4d55ef02982d1  5ea2305993f4d55ef02982cd  macho  flx2.5mg
# 7   5ea2305993f4d55ef02982da  5ea2305993f4d55ef02982d6  macho  flx2.5mg
# 8   5ea2305993f4d55ef02982e3  5ea2305993f4d55ef02982df  macho  flx2.5mg
# 9   5ea2305a93f4d55ef02982ec  5ea2305a93f4d55ef02982e8  macho  flx2.5mg
# 10  5ea2305a93f4d55ef02982f5  5ea2305a93f4d55ef02982f1  macho  flx2.5mg
# 11  5ea2305a93f4d55ef02982fe  5ea2305a93f4d55ef02982fa  macho  flx2.5mg
# 12  5ea2305d93f4d55ef029834f  5ea2305d93f4d55ef029834b  macho  veiculo
# 13  5ea2305e93f4d55ef0298358  5ea2305e93f4d55ef0298354  macho  veiculo
# 14  5ea2305e93f4d55ef0298361  5ea2305e93f4d55ef029835d  macho  veiculo
# 15  5ea2305e93f4d55ef029836a  5ea2305e93f4d55ef0298366  macho  veiculo
# 16  5ea2305f93f4d55ef0298373  5ea2305f93f4d55ef029836f  macho  veiculo
# 17  5ea2305f93f4d55ef029837c  5ea2305f93f4d55ef0298378  macho  veiculo
#
#    unidade
# 0   A1
# 1   A2
# 5   A3
# 6   A4
# 7   A5
# 8   A6
# 9   A6
# 10  A6
# 11  A6
# 12  A1
# 13  A2
# 14  A3
# 15  A4
# 16  A5
# 17  A6

# %%
df = df.drop([9, 10, 11])
df
# Out:
#     d_e_Immobility_s  d_total_experimento  \
# 0   31.466667         297.500000
# 1   34.566667         247.800000
# 5   119.900000        246.666667
# 6   64.633333         245.700000
# 7   87.966667         247.500000
# 8   79.466667         247.700000
# 12  54.900000         269.033333
# 13  128.533333        247.666667
# 14  87.866667         247.333333
# 15  58.066667         247.533333
# 16  109.000000        245.633333
# 17  75.400000         248.533333
#
#                                                      path_experimento  \
# 0   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1e4hb4.vxml
# 1   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 5   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3eh3d23.vxml
# 6   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e6hf2.vxml
# 7   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5eh7g8.vxml
# 8   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 12  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2oh6b8.vxml
# 13  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/8o6hc5.vxml
# 14  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1oh5d5.vxml
# 15  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o8hf5.vxml
# 16  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3oh8g9.vxml
# 17  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5oh7h6.vxml
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5ea2305793f4d55ef029829b  5ea2305793f4d55ef0298297  macho  flx2.5mg
# 1   5ea2305793f4d55ef02982a4  5ea2305793f4d55ef02982a0  macho  flx2.5mg
# 5   5ea2305893f4d55ef02982c8  5ea2305893f4d55ef02982c4  macho  flx2.5mg
# 6   5ea2305993f4d55ef02982d1  5ea2305993f4d55ef02982cd  macho  flx2.5mg
# 7   5ea2305993f4d55ef02982da  5ea2305993f4d55ef02982d6  macho  flx2.5mg
# 8   5ea2305993f4d55ef02982e3  5ea2305993f4d55ef02982df  macho  flx2.5mg
# 12  5ea2305d93f4d55ef029834f  5ea2305d93f4d55ef029834b  macho  veiculo
# 13  5ea2305e93f4d55ef0298358  5ea2305e93f4d55ef0298354  macho  veiculo
# 14  5ea2305e93f4d55ef0298361  5ea2305e93f4d55ef029835d  macho  veiculo
# 15  5ea2305e93f4d55ef029836a  5ea2305e93f4d55ef0298366  macho  veiculo
# 16  5ea2305f93f4d55ef0298373  5ea2305f93f4d55ef029836f  macho  veiculo
# 17  5ea2305f93f4d55ef029837c  5ea2305f93f4d55ef0298378  macho  veiculo
#
#    unidade
# 0   A1
# 1   A2
# 5   A3
# 6   A4
# 7   A5
# 8   A6
# 12  A1
# 13  A2
# 14  A3
# 15  A4
# 16  A5
# 17  A6

# %%
df.to_csv('Dados_duracao_macho.csv', index=False)
