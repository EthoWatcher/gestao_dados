# %%
import deposito_watcher.fusao_variaveis as fus
import pandas as pd
from bson.objectid import ObjectId
import deposito_watcher.querys_feitas as qf

# %%
ID_EXPERIMENTO = "5f8f5503d3d64947e0da22e0"

# %%
dict_query = { "$and": [{"id_experimento": ObjectId(ID_EXPERIMENTO)}, 
                        {"var_ind.sexo":"macho"},
                        {"$or": [{"var_ind.dosagem": "flx2.5mg"},
                                 {"var_ind.dosagem": "veiculo"}
                        ]}]}

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# c:\users\zn_jo\anaconda3\envs\fun\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
fs = fus.Fusao_variaveis(dict_query)

# %%
# fs.set_variaveis_rastreamento(["@Vd", "@Van"])
# fs.set_variaveis_etografia(["nome"])
# list_des_etografia =["nome"]
# fs.set_variaveis_etografia(list_des_etografia)



lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)


li_str_descritores = ["duracao", "duracao_total", "path_experimento"]
li_str_categora = ["Immobility"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#     d_e_Immobility_s  d_total_experimento  \
# 0   31.466667         297.500000
# 1   34.566667         247.800000
# 2   47.900000         247.800000
# 3   33.600000         244.400000
# 4   47.466667         246.433333
# 5   119.900000        246.666667
# 6   64.633333         245.700000
# 7   87.966667         247.500000
# 8   79.466667         247.700000
# 9   92.466667         247.233333
# 10  92.233333         247.700000
# 11  92.666667         246.900000
# 12  54.900000         269.033333
# 13  128.533333        247.666667
# 14  87.866667         247.333333
# 15  58.066667         247.533333
# 16  109.000000        245.633333
# 17  75.400000         248.533333
#
#                                                          path_experimento  \
# 0   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1e4hb4.vxml
# 1   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 2   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 3   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/52e03hc52a.vxml
# 4   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/22e31hc25b.vxml
# 5   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3eh3d23.vxml
# 6   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e6hf2.vxml
# 7   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5eh7g8.vxml
# 8   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 9   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6bis4.vxml
# 10  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 11  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/9e5h4h6b.vxml
# 12  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2oh6b8.vxml
# 13  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/8o6hc5.vxml
# 14  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1oh5d5.vxml
# 15  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o8hf5.vxml
# 16  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3oh8g9.vxml
# 17  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5oh7h6.vxml
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5f8f5507d3d64947e0da2327  5f8f5507d3d64947e0da2323  macho  flx2.5mg
# 1   5f8f5508d3d64947e0da232f  5f8f5508d3d64947e0da232b  macho  flx2.5mg
# 2   5f8f5508d3d64947e0da2337  5f8f5508d3d64947e0da2333  macho  flx2.5mg
# 3   5f8f5509d3d64947e0da233f  5f8f5509d3d64947e0da233b  macho  flx2.5mg
# 4   5f8f550ad3d64947e0da2347  5f8f550ad3d64947e0da2343  macho  flx2.5mg
# 5   5f8f550ad3d64947e0da234f  5f8f550ad3d64947e0da234b  macho  flx2.5mg
# 6   5f8f550bd3d64947e0da2357  5f8f550bd3d64947e0da2353  macho  flx2.5mg
# 7   5f8f550bd3d64947e0da235f  5f8f550bd3d64947e0da235b  macho  flx2.5mg
# 8   5f8f550cd3d64947e0da2367  5f8f550cd3d64947e0da2363  macho  flx2.5mg
# 9   5f8f550cd3d64947e0da236f  5f8f550cd3d64947e0da236b  macho  flx2.5mg
# 10  5f8f550dd3d64947e0da2377  5f8f550dd3d64947e0da2373  macho  flx2.5mg
# 11  5f8f550dd3d64947e0da237f  5f8f550dd3d64947e0da237b  macho  flx2.5mg
# 12  5f8f5511d3d64947e0da23c7  5f8f5511d3d64947e0da23c3  macho  veiculo
# 13  5f8f5512d3d64947e0da23cf  5f8f5512d3d64947e0da23cb  macho  veiculo
# 14  5f8f5512d3d64947e0da23d7  5f8f5512d3d64947e0da23d3  macho  veiculo
# 15  5f8f5513d3d64947e0da23df  5f8f5513d3d64947e0da23db  macho  veiculo
# 16  5f8f5513d3d64947e0da23e7  5f8f5513d3d64947e0da23e3  macho  veiculo
# 17  5f8f5514d3d64947e0da23ef  5f8f5514d3d64947e0da23eb  macho  veiculo
#
#    unidade
# 0   A1
# 1   A2
# 2   A2
# 3   A2
# 4   A2
# 5   A3
# 6   A4
# 7   A5
# 8   A6
# 9   A6
# 10  A6
# 11  A6
# 12  A1
# 13  A2
# 14  A3
# 15  A4
# 16  A5
# 17  A6

# %%
dict_query = { "$and": [{"id_experimento": ObjectId(ID_EXPERIMENTO)}, 
                        {"var_ind.sexo":"macho"},
                        {"var_ind.dosagem": "flx2.5mg"}]}

lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)

list_var_rastreamento =["@Vd", "@Van"]
de_ras = qf.Constru_descritor_rastreamento(list_var_rastreamento, dict_query)


result = de_ras.get_descritor()

# %%
result
# Out:
#         @f         @Vd       @Van                      id_j
# 0     109   0.000000    0.000000   5f8f5507d3d64947e0da2323
# 1     110   0.000000    0.000000   5f8f5507d3d64947e0da2323
# 2     111   0.000000    0.000000   5f8f5507d3d64947e0da2323
# 3     112  -153.118027 -37.579400  5f8f5507d3d64947e0da2323
# 4     113   7.430417    1.823630   5f8f5507d3d64947e0da2323
# ...   ...        ...         ...                        ...
# 7403  7516  0.000000    0.000000   5f8f550dd3d64947e0da237b
# 7404  7517  19.295688   4.571380   5f8f550dd3d64947e0da237b
# 7405  7518  0.000000    0.000000   5f8f550dd3d64947e0da237b
# 7406  7519 -9.386228   -2.223710   5f8f550dd3d64947e0da237b
# 7407  7520  2.059566    0.487936   5f8f550dd3d64947e0da237b
#
# [90383 rows x 4 columns]

# %%
dict_query = { "$and": [{"id_experimento": ObjectId(ID_EXPERIMENTO)}, 
                        {"var_ind.sexo":"macho"},
                        {"var_ind.dosagem": "flx2.5mg"}]}

# %%
fs = fus.Fusao_variaveis(dict_query)

fs.set_variaveis_rastreamento(["@Vd"])
fs.set_variaveis_etografia(["nome", "trecho", "q_inicial", "q_final"])

lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)

li_str_descritores = ["duracao", "frequencia", "duracao_total"]
li_str_categora = ["Swimming"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#      categoria  trecho  q_inicio  q_fim                      id_j    @f  \
# 0     Swimming  1       141       154    5f8f550dd3d64947e0da2373  141
# 1     Swimming  1       141       154    5f8f550dd3d64947e0da2373  142
# 2     Swimming  1       141       154    5f8f550dd3d64947e0da2373  143
# 3     Swimming  1       141       154    5f8f550dd3d64947e0da2373  144
# 4     Swimming  1       141       154    5f8f550dd3d64947e0da2373  145
# ...        ... ..       ...       ...                         ...  ...
# 5539  Swimming  128     7408      7432   5f8f550bd3d64947e0da2353  7427
# 5540  Swimming  128     7408      7432   5f8f550bd3d64947e0da2353  7428
# 5541  Swimming  128     7408      7432   5f8f550bd3d64947e0da2353  7429
# 5542  Swimming  128     7408      7432   5f8f550bd3d64947e0da2353  7430
# 5543  Swimming  128     7408      7432   5f8f550bd3d64947e0da2353  7431
#
#              @Vd  d_e_Swimming_s  f_e_Swimming_s  d_total_experimento  \
# 0     0.000000    25.300000       53              247.7
# 1    -14.263912   25.300000       53              247.7
# 2     0.000000    25.300000       53              247.7
# 3    -11.237550   25.300000       53              247.7
# 4     0.000000    25.300000       53              247.7
# ...        ...          ...       ..                ...
# 5539  0.506641    12.966667       29              245.7
# 5540  120.405871  12.966667       29              245.7
# 5541 -119.969207  12.966667       29              245.7
# 5542  0.000000    12.966667       29              245.7
# 5543  0.381277    12.966667       29              245.7
#
#                         id_eto
# 0     5f8f550dd3d64947e0da2377
# 1     5f8f550dd3d64947e0da2377
# 2     5f8f550dd3d64947e0da2377
# 3     5f8f550dd3d64947e0da2377
# 4     5f8f550dd3d64947e0da2377
# ...                        ...
# 5539  5f8f550bd3d64947e0da2357
# 5540  5f8f550bd3d64947e0da2357
# 5541  5f8f550bd3d64947e0da2357
# 5542  5f8f550bd3d64947e0da2357
# 5543  5f8f550bd3d64947e0da2357
#
# [5544 rows x 11 columns]
