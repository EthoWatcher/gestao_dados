# %%
import pymc3 as pm
import numpy as np

# %%
with pm.Model() as model:
    
    p = pm.Uniform("p", lower=0,upper=1)
    w = pm.Binomial("w",5, p)

# %%
model.logp({'w': 0})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-288f3712f7bb> in <module>
# ----> 1 model.logp({'w': 0})
#       2
#       3
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pymc3\model.py in __call__(self, *args, **kwargs)
#    1280     def __call__(self, *args, **kwargs):
#    1281         point = Point(model=self.model, *args, **kwargs)
# -> 1282         return self.f(**point)
#    1283
#    1284 compilef = fastfn
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     884                     raise TypeError("Missing required input: %s" %
#     885                                     getattr(self.inv_finder[c], 'variable',
# --> 886                                             self.inv_finder[c]))
#     887                 if c.provided > 1:
# ...

# %%
data = 4 + np.random.rand(100,1)
with pm.Model() as m1:
    m_u = pm.Normal("m_u", mu=0, sd=20)
    likelihodd = pm.Normal("y", mu=m_u, sd=1, observed=data)
    trace =  pm.sample(500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [m_u]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:03<00:00, 1310.73draws/s]
# The acceptance probability does not match the target. It is 0.8986102050423711, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8810484326569754, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A2520E89C8>,
# ...
#       dtype=object)

# %%
model.basic_RVs

# %%
from pymc3 import plot_posterior

# %%
plot_posterior

# %%
# Out:
# [p_interval__, w]
